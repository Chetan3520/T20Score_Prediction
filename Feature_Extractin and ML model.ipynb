# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#data-Extracton" data-toc-modified-id="data-Extracton-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>data Extracton</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#The-necessary-features-corresponding-for-ML-model" data-toc-modified-id="The-necessary-features-corresponding-for-ML-model-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>The necessary features corresponding for ML model</a></span></li><li><span><a href="#check-null-values" data-toc-modified-id="check-null-values-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>check null values</a></span></li><li><span><a href="#how-many-cities-which-have-null-values-corresponding-to-venue?" data-toc-modified-id="how-many-cities-which-have-null-values-corresponding-to-venue?-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>how many cities which have null values corresponding to venue?</a></span></li><li><span><a href="#(city-has-null-values-because-we-can-observe-that-the-cities-are-mention-in-corresponding-venue-column-so-lets-extract-that-cities-from-venue-column)" data-toc-modified-id="(city-has-null-values-because-we-can-observe-that-the-cities-are-mention-in-corresponding-venue-column-so-lets-extract-that-cities-from-venue-column)-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>(city has null values because we can observe that the cities are mention in corresponding venue column so lets extract that cities from venue column)</a></span></li><li><span><a href="#Going-to-apply-threshold-that-will-consider-city-eligible-when-at-least-600-matches-played-in-that-city" data-toc-modified-id="Going-to-apply-threshold-that-will-consider-city-eligible-when-at-least-600-matches-played-in-that-city-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>Going to apply threshold that will consider city eligible when at least 600 matches played in that city</a></span></li><li><span><a href="#seperate-the-ball-and-over-values-and-add-the-new-columns-in-the-data" data-toc-modified-id="seperate-the-ball-and-over-values-and-add-the-new-columns-in-the-data-1.0.6"><span class="toc-item-num">1.0.6&nbsp;&nbsp;</span>seperate the ball and over values and add the new columns in the data</a></span></li><li><span><a href="#Find-out-the-numbers-of-balls-bowled" data-toc-modified-id="Find-out-the-numbers-of-balls-bowled-1.0.7"><span class="toc-item-num">1.0.7&nbsp;&nbsp;</span>Find out the numbers of balls bowled</a></span></li><li><span><a href="#find-out-balls-left" data-toc-modified-id="find-out-balls-left-1.0.8"><span class="toc-item-num">1.0.8&nbsp;&nbsp;</span>find out balls left</a></span></li><li><span><a href="#find-out-how-many-wickets-left" data-toc-modified-id="find-out-how-many-wickets-left-1.0.9"><span class="toc-item-num">1.0.9&nbsp;&nbsp;</span>find out how many wickets left</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## data Extracton

# %%
import pandas as pd
import pickle
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %% [markdown]
# #### The necessary features corresponding for ML model

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                0  \
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# ...

# %% [markdown]
# #### check null values

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %% [markdown]
# #### how many cities which have null values corresponding to venue?

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %% [markdown]
# #### (city has null values because we can observe that the cities are mention in corresponding venue column so lets extract that cities from venue column)

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                0  \
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %% [markdown]
# #### Going to apply threshold that will consider city eligible when at least 600 matches played in that city

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)];df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                0  \
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
#df.groupby('match_id').cumsum()['runs']

# %% [markdown]
# #### seperate the ball and over values and add the new columns in the data

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                0  \
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no
# 0       Melbourne              0    0       1
# ...

# %% [markdown]
# #### Find out the numbers of balls bowled

# %% [markdown]
# no of balls bowled= over no. *6+ current ball no

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                0  \
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled
# ...

# %% [markdown]
# #### find out balls left

# %%
df['balls_left'] = 120 - df['balls_bowled']
#balls may be more than 120 for that this code will give negative values to avoid this,
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                0  \
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled  balls_left
# ...

# %% [markdown]
# #### find out how many wickets left

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                 0  \
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left
# ...

# %%
df['wickets_left']=10-df['player_dismissed']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                 0  \
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left
# ...

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs  player_dismissed
# 0         2    Australia    Sri Lanka   0.1     0                 0  \
# 1         2    Australia    Sri Lanka   0.2     0                 0
# 2         2    Australia    Sri Lanka   0.3     1                 0
# 3         2    Australia    Sri Lanka   0.4     2                 0
# 4         2    Australia    Sri Lanka   0.5     0                 0
#
#         city  current_score over ball_no  balls_bowled  balls_left
# 0  Melbourne              0    0       1             1         119  \
# 1  Melbourne              0    0       2             2         118
# 2  Melbourne              1    0       3             3         117
# 3  Melbourne              3    0       4             4         116
# 4  Melbourne              3    0       5             5         115
#
#    wickets_left
# 0            10
# 1            10
# 2            10
# 3            10
# 4            10

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed
# 0              2    Australia    Sri Lanka   0.1     0                 0  \
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left
# ...

# %%
print(df['runs'].dtype)
# Out:
# int64

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs'].sum().values.tolist())

# %%
df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.to_excel('T20.xlsx',index=False)

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team        city  current_score  balls_left
# 38550  West Indies  New Zealand  Wellington             93          36  \
# 2696      Pakistan  West Indies    Trinidad             77          39
#
#        wickets_left       crr  last_five  runs_x
# 38550             6  6.642857       29.0     159
# 2696              6  5.703704       34.0     132

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train

# %%
X_train.columns

# %%
#!pip install xgboost==1.4.2

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
#import xgboost
xgboost.__version__

# %%
import pandas as pd

# %%
d=pd.read_excel("T20.xlsx")

# %%
d.shape
# Out:
# (38477, 9)

# %%
d.columns
# Out:
# Index(['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left',
#        'wickets_left', 'crr', 'last_five', 'runs_x'],
#       dtype='object')

# %%
grouped_df = d.groupby(['batting_team', 'wickets_left']).agg({'runs_x': 'max', 'crr': 'max'})

# %%
grouped_df_sorted = grouped_df.sort_values(['runs_x', 'crr'], ascending=False)

# %%
grouped_df_sorted
# Out:
#                            runs_x        crr
# batting_team wickets_left
# Australia    10               263  13.354839
#              8                263  13.260504
#              7                263  13.150000
#              9                263  12.727273
#              6                248  12.849057
# ...                           ...        ...
# South Africa 0                133   6.820513
# Pakistan     0                132   6.600000
# Afghanistan  2                115   5.750000
#              1                110   5.546218
#              0                110   5.500000
#
# [109 rows x 2 columns]

# %%
np.sort(d.batting_team.unique())
# Out:
# array(['Afghanistan', 'Australia', 'Bangladesh', 'England', 'India',
#        'New Zealand', 'Pakistan', 'South Africa', 'Sri Lanka',
#        'West Indies'], dtype=object)

# %%
['Afghanistan', 'Australia', 'Bangladesh', 'England', 'India',
       'New Zealand', 'Pakistan', 'South Africa', 'Sri Lanka',
       'West Indies']

# %%
d.
